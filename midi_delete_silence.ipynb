# %% [markdown]
# В этом файле я удаляю тишину и паузы из миди файлов

# %%
import os
import pretty_midi

midi_folder = "lmd_full/a/balanced_instruments"

INSTRUMENT_NOTES = {
    'Accordion': (40, 108),
    'Acoustic Bass': (28, 67),
    'Acoustic Guitar _nylon': (52, 91),
    'Acoustic Guitar _steel': (52, 91),
    'Acoustic Grand Piano': (21, 108),
    'Alto Sax': (58, 90),
    'Bagpipe': (62, 81),
    'Banjo': (55, 79),
    'Baritone Sax': (58, 90),
    'Bassoon': (35, 77),
    'Bright Acoustic Piano': (21, 108),
    'Celesta': (60, 108),
    'Cello': (36, 81),
    'Church Organ': (36, 96),
    'Clarinet': (52, 91),
    'Contrabass': (28, 71),
    'Dulcimer': (48, 96),
    'English Horn': (48, 83),
    'Fiddle': (55, 105),
    'Flute': (60, 96),
    'French Horn': (35, 77),
    'Glockenspiel': (77, 108),
    'Guitar Harmonics': (59, 101),
    'Harmonica': (54, 96),
    'Harpsichord': (29, 89),
    'Kalimba': (50, 89),
    'Marimba': (36, 96),
    'Muted Trumpet': (54, 84),
    'Oboe': (58, 89),
    'Ocarina': (55, 96),
    'Orchestral Harp': (29, 103),
    'Pan Flute': (36, 93),
    'Percussive Organ': (36, 96),
    'Piccolo': (74, 108),
    'Pizzicato Strings': (28, 100),
    'Timpani': (74, 93),
    'Tinkle Bell': (84, 115),
    'Tremolo Strings': (28, 100),
    'Trombone': (31, 77),
    'Trumpet': (60, 83),
    'Tuba': (24, 64),
    'Tubular Bells': (55, 84),
    'Vibraphone': (48, 96),
    'Viola': (48, 88),
    'Violin': (55, 105),
    'Xylophone': (53, 96)
}

def is_valid_instrument(instrument_name):
    return instrument_name in INSTRUMENT_NOTES


def remove_midi_pauses(midi_path, output_path=None):
    try:        
        midi = pretty_midi.PrettyMIDI(midi_folder+"/"+midi_path)
    
        instrument_name = midi_path.split('.')[0]
        
        all_notes = [note for inst in midi.instruments for note in inst.notes]
    
        if not all_notes:
            return False
    
        if not is_valid_instrument(instrument_name):
            print(f"Пропущен (невалидный инструмент): {instrument_name}")
            return False
    
        instrument_range = INSTRUMENT_NOTES[instrument_name]

        first_note_start = min(n.start for n in all_notes)
        last_note_end = max(n.end for n in all_notes)
    
        for instrument in midi.instruments:
            if not instrument.notes:
                continue
            
            if not instrument_range:
                continue
            
            valid_notes = []
            current_time = 0.0
            
            instrument.notes.sort(key=lambda x: x.start)
        
            time_shift = first_note_start
            current_time = 0.0
        
            new_notes = []
        
            total_duration = sum(note.end - note.start for note in instrument.notes)
        
            current_time = 0.0
            
            for note in instrument.notes:
                if instrument_range[0] <= note.pitch <= instrument_range[1]:
                    note_duration = note.end - note.start
                    note.start = current_time
                    note.end = current_time + note_duration
                    current_time += note_duration
                    valid_notes.append(note)
        
            instrument.notes = valid_notes
        
        if output_path is None:
            base, ext = os.path.splitext(midi_path)
            output_path = f"{midi_folder}/valid/{base}_no_pauses{ext}"
            
        midi.instruments = [inst for inst in midi.instruments if inst.notes]

        if not midi.instruments:
            print(f"Пропущен (нет валидных нот): {instrument_name}")
            return False

        midi.write(output_path)
        print(f"Успешно обработан: {instrument_name}")
        return True
    
    except Exception as e:
        print(f"Ошибка при обработке {midi_path}: {str(e)}")
        return False


for file in os.listdir(midi_folder):
    if file.endswith('.mid'):
        remove_midi_pauses(file)
        print("Changed "+file)
# Out:
# Успешно обработан: Accordion
# Changed Accordion.mid
# Успешно обработан: Acoustic Bass
# Changed Acoustic Bass.mid
# Успешно обработан: Acoustic Grand Piano
# Changed Acoustic Grand Piano.mid
# Пропущен (невалидный инструмент): Acoustic Guitar _nylon_
# Changed Acoustic Guitar _nylon_.mid
# Пропущен (невалидный инструмент): Acoustic Guitar _steel_
# Changed Acoustic Guitar _steel_.mid
# Пропущен (невалидный инструмент): Agogo
# Changed Agogo.mid
# Успешно обработан: Alto Sax
# Changed Alto Sax.mid
# Пропущен (невалидный инструмент): Applause
# Changed Applause.mid
# Успешно обработан: Bagpipe
# Changed Bagpipe.mid
# Успешно обработан: Banjo
# Changed Banjo.mid
# Пропущен (невалидный инструмент): Baritone Sax
# Changed Baritone Sax.mid
# Успешно обработан: Bassoon
# Changed Bassoon.mid
# Пропущен (невалидный инструмент): Bird Tweet
# Changed Bird Tweet.mid
# Пропущен (невалидный инструмент): Blown Bottle
# Changed Blown Bottle.mid
# Пропущен (невалидный инструмент): Brass Section
# Changed Brass Section.mid
# Пропущен (невалидный инструмент): Breath Noise
# Changed Breath Noise.mid
# Успешно обработан: Bright Acoustic Piano
# Changed Bright Acoustic Piano.mid
# Успешно обработан: Celesta
# Changed Celesta.mid
# Успешно обработан: Cello
# Changed Cello.mid
# Пропущен (невалидный инструмент): Choir Aahs
# Changed Choir Aahs.mid
# Успешно обработан: Church Organ
# Changed Church Organ.mid
# Успешно обработан: Clarinet
# Changed Clarinet.mid
# Пропущен (невалидный инструмент): Clavinet
# Changed Clavinet.mid
# Успешно обработан: Contrabass
# Changed Contrabass.mid
# Пропущен (невалидный инструмент): Distortion Guitar
# Changed Distortion Guitar.mid
# Пропущен (невалидный инструмент): Drawbar Organ
# Changed Drawbar Organ.mid
# Успешно обработан: Dulcimer
# Changed Dulcimer.mid
# Пропущен (невалидный инструмент): Electric Bass _finger_
# Changed Electric Bass _finger_.mid
# Пропущен (невалидный инструмент): Electric Bass _pick_
# Changed Electric Bass _pick_.mid
# Пропущен (невалидный инструмент): Electric Grand Piano
# Changed Electric Grand Piano.mid
# Пропущен (невалидный инструмент): Electric Guitar _clean_
# Changed Electric Guitar _clean_.mid
# Пропущен (невалидный инструмент): Electric Guitar _jazz_
# Changed Electric Guitar _jazz_.mid
# Пропущен (невалидный инструмент): Electric Guitar _muted_
# Changed Electric Guitar _muted_.mid
# Пропущен (невалидный инструмент): Electric Piano 1
# Changed Electric Piano 1.mid
# Пропущен (невалидный инструмент): Electric Piano 2
# Changed Electric Piano 2.mid
# Успешно обработан: English Horn
# Changed English Horn.mid
# Успешно обработан: Fiddle
# Changed Fiddle.mid
# Успешно обработан: Flute
# Changed Flute.mid
# Успешно обработан: French Horn
# Changed French Horn.mid
# Пропущен (невалидный инструмент): Fretless Bass
# Changed Fretless Bass.mid
# Пропущен (невалидный инструмент): FX 1 _rain_
# Changed FX 1 _rain_.mid
# Пропущен (невалидный инструмент): FX 2 _soundtrack_
# Changed FX 2 _soundtrack_.mid
# Пропущен (невалидный инструмент): FX 3 _crystal_
# Changed FX 3 _crystal_.mid
# Пропущен (невалидный инструмент): FX 4 _atmosphere_
# Changed FX 4 _atmosphere_.mid
# Пропущен (невалидный инструмент): FX 5 _brightness_
# Changed FX 5 _brightness_.mid
# Пропущен (невалидный инструмент): FX 6 _goblins_
# Changed FX 6 _goblins_.mid
# Пропущен (невалидный инструмент): FX 7 _echoes_
# Changed FX 7 _echoes_.mid
# Пропущен (невалидный инструмент): FX 8 _sci_fi_
# Changed FX 8 _sci_fi_.mid
# Успешно обработан: Glockenspiel
# Changed Glockenspiel.mid
# Пропущен (невалидный инструмент): Guitar Fret Noise
# Changed Guitar Fret Noise.mid
# Успешно обработан: Guitar Harmonics
# Changed Guitar Harmonics.mid
# Пропущен (невалидный инструмент): Gunshot
# Changed Gunshot.mid
# Успешно обработан: Harmonica
# Changed Harmonica.mid
# Пропущен (невалидный инструмент): Harpsichord
# Changed Harpsichord.mid
# Пропущен (невалидный инструмент): Helicopter
# Changed Helicopter.mid
# Пропущен (невалидный инструмент): Honky_tonk Piano
# Changed Honky_tonk Piano.mid
# Успешно обработан: Kalimba
# Changed Kalimba.mid
# Пропущен (невалидный инструмент): Koto
# Changed Koto.mid
# Пропущен (невалидный инструмент): Lead 1 _square_
# Changed Lead 1 _square_.mid
# Пропущен (невалидный инструмент): Lead 2 _sawtooth_
# Changed Lead 2 _sawtooth_.mid
# Пропущен (невалидный инструмент): Lead 3 _calliope_
# Changed Lead 3 _calliope_.mid
# Пропущен (невалидный инструмент): Lead 4 _chiff_
# Changed Lead 4 _chiff_.mid
# Пропущен (невалидный инструмент): Lead 5 _charang_
# Changed Lead 5 _charang_.mid
# Пропущен (невалидный инструмент): Lead 6 _voice_
# Changed Lead 6 _voice_.mid
# Пропущен (невалидный инструмент): Lead 7 _fifths_
# Changed Lead 7 _fifths_.mid
# Пропущен (невалидный инструмент): Lead 8 _bass _ lead_
# Changed Lead 8 _bass _ lead_.mid
# Успешно обработан: Marimba
# Changed Marimba.mid
# Пропущен (невалидный инструмент): Melodic Tom
# Changed Melodic Tom.mid
# Пропущен (невалидный инструмент): Music Box
# Changed Music Box.mid
# Успешно обработан: Muted Trumpet
# Changed Muted Trumpet.mid
# Успешно обработан: Oboe
# Changed Oboe.mid
# Успешно обработан: Ocarina
# Changed Ocarina.mid
# Пропущен (невалидный инструмент): Orchestra Hit
# Changed Orchestra Hit.mid
# Успешно обработан: Orchestral Harp
# Changed Orchestral Harp.mid
# Пропущен (невалидный инструмент): Overdriven Guitar
# Changed Overdriven Guitar.mid
# Пропущен (невалидный инструмент): Pad 1 _new age_
# Changed Pad 1 _new age_.mid
# Пропущен (невалидный инструмент): Pad 2 _warm_
# Changed Pad 2 _warm_.mid
# Пропущен (невалидный инструмент): Pad 3 _polysynth_
# Changed Pad 3 _polysynth_.mid
# Пропущен (невалидный инструмент): Pad 4 _choir_
# Changed Pad 4 _choir_.mid
# Пропущен (невалидный инструмент): Pad 5 _bowed_
# Changed Pad 5 _bowed_.mid
# Пропущен (невалидный инструмент): Pad 6 _metallic_
# Changed Pad 6 _metallic_.mid
# Пропущен (невалидный инструмент): Pad 7 _halo_
# Changed Pad 7 _halo_.mid
# Пропущен (невалидный инструмент): Pad 8 _sweep_
# Changed Pad 8 _sweep_.mid
# Успешно обработан: Pan Flute
# Changed Pan Flute.mid
# Успешно обработан: Percussive Organ
# Changed Percussive Organ.mid
# Успешно обработан: Piccolo
# Changed Piccolo.mid
# Успешно обработан: Pizzicato Strings
# Changed Pizzicato Strings.mid
# Пропущен (невалидный инструмент): Recorder
# Changed Recorder.mid
# Пропущен (невалидный инструмент): Reed Organ
# Changed Reed Organ.mid
# Пропущен (невалидный инструмент): Reverse Cymbal
# Changed Reverse Cymbal.mid
# Пропущен (невалидный инструмент): Rock Organ
# Changed Rock Organ.mid
# Пропущен (невалидный инструмент): Seashore
# Changed Seashore.mid
# Пропущен (невалидный инструмент): Shakuhachi
# Changed Shakuhachi.mid
# Пропущен (невалидный инструмент): Shamisen
# Changed Shamisen.mid
# Пропущен (невалидный инструмент): Shanai
# Changed Shanai.mid
# Пропущен (невалидный инструмент): Sitar
# Changed Sitar.mid
# Пропущен (невалидный инструмент): Slap Bass 1
# Changed Slap Bass 1.mid
# Пропущен (невалидный инструмент): Slap Bass 2
# Changed Slap Bass 2.mid
# Пропущен (невалидный инструмент): Soprano Sax
# Changed Soprano Sax.mid
# Пропущен (невалидный инструмент): Steel Drums
# Changed Steel Drums.mid
# Пропущен (невалидный инструмент): String Ensemble 1
# Changed String Ensemble 1.mid
# Пропущен (невалидный инструмент): String Ensemble 2
# Changed String Ensemble 2.mid
# Пропущен (невалидный инструмент): Synth Bass 1
# Changed Synth Bass 1.mid
# Пропущен (невалидный инструмент): Synth Bass 2
# Changed Synth Bass 2.mid
# Пропущен (невалидный инструмент): Synth Brass 1
# Changed Synth Brass 1.mid
# Пропущен (невалидный инструмент): Synth Brass 2
# Changed Synth Brass 2.mid
# Пропущен (невалидный инструмент): Synth Drum
# Changed Synth Drum.mid
# Пропущен (невалидный инструмент): Synth Strings 1
# Changed Synth Strings 1.mid
# Пропущен (невалидный инструмент): Synth Strings 2
# Changed Synth Strings 2.mid
# Пропущен (невалидный инструмент): Synth Voice
# Changed Synth Voice.mid
# Пропущен (невалидный инструмент): Taiko Drum
# Changed Taiko Drum.mid
# Пропущен (невалидный инструмент): Tango Accordion
# Changed Tango Accordion.mid
# Пропущен (невалидный инструмент): Telephone Ring
# Changed Telephone Ring.mid
# Пропущен (невалидный инструмент): Tenor Sax
# Changed Tenor Sax.mid
# Успешно обработан: Timpani
# Changed Timpani.mid
# Успешно обработан: Tinkle Bell
# Changed Tinkle Bell.mid
# Успешно обработан: Tremolo Strings
# Changed Tremolo Strings.mid
# Успешно обработан: Trombone
# Changed Trombone.mid
# Успешно обработан: Trumpet
# Changed Trumpet.mid
# Успешно обработан: Tuba
# Changed Tuba.mid
# Успешно обработан: Tubular Bells
# Changed Tubular Bells.mid
# Успешно обработан: Vibraphone
# Changed Vibraphone.mid
# Успешно обработан: Viola
# Changed Viola.mid
# Успешно обработан: Violin
# Changed Violin.mid
# Пропущен (невалидный инструмент): Voice Oohs
# Changed Voice Oohs.mid
# Пропущен (невалидный инструмент): Whistle
# Changed Whistle.mid
# Пропущен (невалидный инструмент): Woodblock
# Changed Woodblock.mid
# Успешно обработан: Xylophone
# Changed Xylophone.mid
